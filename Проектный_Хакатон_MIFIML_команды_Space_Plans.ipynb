# %% [markdown]
# # Проектный Хакатон MIFIML команды Space Plans

# %% [markdown]
# ## Структура проекта для Хакатона MEPHI-ML

# %% [markdown]
# ### Вводные данные
# **Название команды(Рабочее):** Space plans
#
# **Структура команды:**
#
# * **Team leader:** Кловер Натан ( Clover9301@gmail.com )
#
# * **Product manager:** Воронин Михаил Михайлович ( mixan2912@gmail.com )
#
# * **Analytics team:**
#   * Прокофьев Михаил Всеволодович ( k0rsair@mail.ru )
#   * Жадаев Василий Васильевич ( st1m_97@mail.ru )
#   * Колотий Марианна Павловна ( mildburg@rambler.ru )
#
# **Тема проекта:**  Мониторинг качества воздуха
#
# **Набор данных:** https://www.kaggle.com/datasets/hasibalmuzdadid/global-air-pollution-dataset

# %% [markdown]
# ---

# %% [markdown]
# ### Бизнес-постановка задачи

# %% [markdown]
# * **Проблема**
#
#   * Окружающая среда постоянно меняется под воздействием природных факторов и деятельности человека. Экологам, научным работникам и представителям власти необходимы достоверные данные для мониторинга состояния экосистем, принятия обоснованных решений по сохранению и реагированию на экологические проблемы. Однако традиционные методы сбора данных трудоемки и часто показывают высокий процент ошибок.
#
#   * Точные и оперативные экологические исследования приобретают все большее значение в связи с усилением антропогенного воздействия и изменением климата. Мониторинг флоры и фауны, качества воздуха, воды и состояния земель требует интеграции различных типов и форматов данных.
#
# * **Цель**
#   1. Интеграция предварительно обученных моделей машинного обучения для анализа данных о загрязнении воздуха, чтобы:
#     * Прогнозировать общий индекс качества воздуха (AQI ).
#     * Классифицировать уровень загрязнения (AQI Category).
#     * Оценивать влияние отдельных загрязнителей (CO, Ozone, NO2, PM2.5) на качество воздуха.
#
# * **Этапы реализации**
#   1. **Подготовка данных:**
#     * Загрузка и очистка табличных данных, содержащих информацию о стране, городе, уровне загрязнения и категории AQI.
#     * Кодирование категориальных данных (Country, City, AQI Category) с использованием методов, таких как Label Encoding.
#
#  2. **Обучение модели:**
#     * Использование предварительно обученных моделей CatBoost для выполнения следующих задач:
#       * Прогнозирование значений AQI Value.
#       * Классификация AQI Category.
#       * Оценка влияния загрязняющих веществ на AQI.
#       * Применение методов машинного обучения для обучения модели с использованием показателей процентного содержания загрязняющих веществ и географическое положение.
#
#   3. **Оценка модели:**
#     * Оценка качества модели с помощью различных метрик:
#     * Для задачи регрессии: Mean Squared Error (MSE), R² Score.
#     * Для задачи классификации: Accuracy
#     * Проведение кросс-валидации для повышения надежности результатов.
#
#   4. **Визуализация и интерпретация результатов:**
#     * Построение графиков важности признаков, чтобы понять, какие вредные вещества оказывают наибольшее влияние на результаты.
#     * Визуализация предсказаний модели и реальных значений AQI.

# %% [markdown]
# ---

# %% [markdown]
# ### Структура данных
#
# <div style="display: flex; justify-content: center; align-items: center; margin: 20px;">
#     <table style="border-collapse: collapse; text-align: left; border: 1px solid #ddd;">
#         <thead>
#             <tr style="background-color: #f2f2f2;">
#                 <th style="padding: 8px; border: 1px solid #ddd;"><strong>Переменная</strong></th>
#                 <th style="padding: 8px; border: 1px solid #ddd;"><strong>Тип</strong></th>
#                 <th style="padding: 8px; border: 1px solid #ddd;"><strong>Описание</strong></th>
#             </tr>
#         </thead>
#         <tbody>
#             <tr>
#                 <th style="padding: 8px; border: 1px solid #ddd;"><em>Country</em></th>
#                 <td style="padding: 8px; border: 1px solid #ddd;">object</td>
#                 <td style="padding: 8px; border: 1px solid #ddd;">Название страны</td>
#             </tr>
#             <tr>
#                 <th style="padding: 8px; border: 1px solid #ddd;"><em>City</em></th>
#                 <td style="padding: 8px; border: 1px solid #ddd;">object</td>
#                 <td style="padding: 8px; border: 1px solid #ddd;">Название города</td>
#             </tr>
#             <tr>
#                 <th style="padding: 8px; border: 1px solid #ddd;"><em>AQI Value</em></th>
#                 <td style="padding: 8px; border: 1px solid #ddd;">int64</td>
#                 <td style="padding: 8px; border: 1px solid #ddd;">Общее значение AQI города</td>
#             </tr>
#             <tr>
#                 <th style="padding: 8px; border: 1px solid #ddd;"><em>AQI Category</em></th>
#                 <td style="padding: 8px; border: 1px solid #ddd;">object</td>
#                 <td style="padding: 8px; border: 1px solid #ddd;">Общая категория AQI города</td>
#             </tr>
#             <tr>
#                 <th style="padding: 8px; border: 1px solid #ddd;"><em>CO AQI Value</em></th>
#                 <td style="padding: 8px; border: 1px solid #ddd;">int64</td>
#                 <td style="padding: 8px; border: 1px solid #ddd;">Значение AQI угарного газа в городе</td>
#             </tr>
#             <tr>
#                 <th style="padding: 8px; border: 1px solid #ddd;"><em>CO AQI Category</em></th>
#                 <td style="padding: 8px; border: 1px solid #ddd;">object</td>
#                 <td style="padding: 8px; border: 1px solid #ddd;">Категория AQI угарного газа в городе</td>
#             </tr>
#             <tr>
#                 <th style="padding: 8px; border: 1px solid #ddd;"><em>Ozone AQI Value</em></th>
#                 <td style="padding: 8px; border: 1px solid #ddd;">int64</td>
#                 <td style="padding: 8px; border: 1px solid #ddd;">Значение AQI озона города</td>
#             </tr>
#             <tr>
#                 <th style="padding: 8px; border: 1px solid #ddd;"><em>Ozone AQI Category</em></th>
#                 <td style="padding: 8px; border: 1px solid #ddd;">object</td>
#                 <td style="padding: 8px; border: 1px solid #ddd;">Категория AQI озона города</td>
#             </tr>
#             <tr>
#                 <th style="padding: 8px; border: 1px solid #ddd;"><em>NO2 AQI Value</em></th>
#                 <td style="padding: 8px; border: 1px solid #ddd;">int64</td>
#                 <td style="padding: 8px; border: 1px solid #ddd;">Значение AQI диоксида азота в городе</td>
#             </tr>
#             <tr>
#                 <th style="padding: 8px; border: 1px solid #ddd;"><em>NO2 AQI Category</em></th>
#                 <td style="padding: 8px; border: 1px solid #ddd;">object</td>
#                 <td style="padding: 8px; border: 1px solid #ddd;">Категория AQI диоксида азота в городе</td>
#             </tr>
#             <tr>
#                 <th style="padding: 8px; border: 1px solid #ddd;"><em>PM2.5 AQI Value</em></th>
#                 <td style="padding: 8px; border: 1px solid #ddd;">int64</td>
#                 <td style="padding: 8px; border: 1px solid #ddd;">Значение AQI для твердых частиц диаметром 2,5 микрометра и менее в городе</td>
#             </tr>
#             <tr>
#                 <th style="padding: 8px; border: 1px solid #ddd;"><em>PM2.5 AQI Category</em></th>
#                 <td style="padding: 8px; border: 1px solid #ddd;">object</td>
#                 <td style="padding: 8px; border: 1px solid #ddd;">Категория AQI для твердых частиц диаметром 2,5 микрометра и менее в городе</td>
#             </tr>
#         </tbody>
#     </table>
# </div>
# * AQI - индекс качества воздуха

# %% [markdown]
# ---

# %% [markdown]
# ### Импорты

# %%
# !pip install catboost

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import shap
import kagglehub
import lightgbm as lgb
from catboost import CatBoostClassifier
from catboost import CatBoostRegressor
from catboost import Pool
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import IsolationForest
# Out:
# Collecting catboost
#   Downloading catboost-1.2.7-cp310-cp310-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.8.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.2.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (9.0.0)
# Downloading catboost-1.2.7-cp310-cp310-manylinux2014_x86_64.whl (98.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 6.3 MB/s eta 0:00:00
# Installing collected packages: catboost
# Successfully installed catboost-1.2.7
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)

# %%
# Загрузка данных из Kaggle
path = kagglehub.dataset_download("hasibalmuzdadid/global-air-pollution-dataset")
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.5), please consider upgrading to the latest version (0.3.6).
# Downloading from https://www.kaggle.com/api/v1/datasets/download/hasibalmuzdadid/global-air-pollution-dataset?dataset_version_number=2...
# 100%|██████████| 371k/371k [00:00<00:00, 727kB/s]
# Extracting files...

# %%
# Создаем DataFrame
try:
    data = pd.read_csv('/root/.cache/kagglehub/datasets/hasibalmuzdadid/global-air-pollution-dataset/versions/2/global air pollution dataset.csv')
    print('Получение данных прошло успешно')
except Exception as e:
    print('Не удалось получить данные')
    print(e)
# Out:
# Получение данных прошло успешно

# %% [markdown]
# ---

# %% [markdown]
# ## Разведывательный анализ данных

# %%
# Выводим информацию о DataFrame
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23463 entries, 0 to 23462
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             23036 non-null  object
#  1   City                23462 non-null  object
#  2   AQI Value           23463 non-null  int64
#  3   AQI Category        23463 non-null  object
#  4   CO AQI Value        23463 non-null  int64
#  5   CO AQI Category     23463 non-null  object
#  6   Ozone AQI Value     23463 non-null  int64
#  7   Ozone AQI Category  23463 non-null  object
#  8   NO2 AQI Value       23463 non-null  int64
#  9   NO2 AQI Category    23463 non-null  object
#  10  PM2.5 AQI Value     23463 non-null  int64
#  11  PM2.5 AQI Category  23463 non-null  object
# dtypes: int64(5), object(7)
# memory usage: 2.1+ MB

# %%
# Проверяем количество пропущенных значений в столбцах
data.isnull().sum()
# Out:
# Country               427
# City                    1
# AQI Value               0
# AQI Category            0
# CO AQI Value            0
# CO AQI Category         0
# Ozone AQI Value         0
# Ozone AQI Category      0
# NO2 AQI Value           0
# NO2 AQI Category        0
# PM2.5 AQI Value         0
# PM2.5 AQI Category      0
# dtype: int64

# %%
data.head()
# Out:
#               Country              City  AQI Value AQI Category  CO AQI Value  \
# 0  Russian Federation        Praskoveya         51     Moderate             1
# 1              Brazil  Presidente Dutra         41         Good             1
# 2               Italy   Priolo Gargallo         66     Moderate             1
# 3              Poland         Przasnysz         34         Good             1
# 4              France          Punaauia         22         Good             0
#
#   CO AQI Category  Ozone AQI Value Ozone AQI Category  NO2 AQI Value  \
# 0            Good               36               Good              0
# 1            Good                5               Good              1
# 2            Good               39               Good              2
# 3            Good               34               Good              0
# 4            Good               22               Good              0
#
#   NO2 AQI Category  PM2.5 AQI Value PM2.5 AQI Category
# 0             Good               51           Moderate
# 1             Good               41               Good
# 2             Good               66           Moderate
# 3             Good               20               Good
# 4             Good                6               Good

# %%
# Преобразуем столбцы City и Country в строки
data['City'] = data['City'].astype(str)
data['Country'] = data['Country'].astype(str)

# Создаем новый столбец, объединяющий City и Country
data['City_Country'] = data['City'] + ' ' + data['Country']

# Вывод уникальных значений
print(data['City_Country'].unique())
# Out:
# ['Praskoveya Russian Federation' 'Presidente Dutra Brazil'
#  'Priolo Gargallo Italy' ... 'Mormugao India'
#  'Westerville United States of America' 'Marang Malaysia']

# %%
#Мапим города и страны
city_map = pd.read_csv('https://raw.githubusercontent.com/k0rsair/Space-plans/refs/heads/main/city_country.csv', header=None, delimiter=';')
for item in city_map.values:
    data.loc[data['City'] == item[0], 'Country'] = item[1]

# %%
#Удалим строку, где мы не знаем город
data.dropna(inplace=True)

# %%
# Проверяем количество пропущенных значений в столбцах после преобразований
data.isnull().sum()
# Out:
# Country               0
# City                  0
# AQI Value             0
# AQI Category          0
# CO AQI Value          0
# CO AQI Category       0
# Ozone AQI Value       0
# Ozone AQI Category    0
# NO2 AQI Value         0
# NO2 AQI Category      0
# PM2.5 AQI Value       0
# PM2.5 AQI Category    0
# City_Country          0
# dtype: int64

# %%
# Проверяем на наличие дублирующихся строк
data.duplicated().sum()
# Out:
# 0

# %%
# Отображает статистику для числовых столбцов
data.describe()
# Out:
#           AQI Value  CO AQI Value  Ozone AQI Value  NO2 AQI Value  \
# count  23463.000000  23463.000000     23463.000000   23463.000000
# mean      72.010868      1.368367        35.193709       3.063334
# std       56.055220      1.832064        28.098723       5.254108
# min        6.000000      0.000000         0.000000       0.000000
# 25%       39.000000      1.000000        21.000000       0.000000
# 50%       55.000000      1.000000        31.000000       1.000000
# 75%       79.000000      1.000000        40.000000       4.000000
# max      500.000000    133.000000       235.000000      91.000000
#
#        PM2.5 AQI Value
# count     23463.000000
# mean         68.519755
# std          54.796443
# min           0.000000
# 25%          35.000000
# 50%          54.000000
# 75%          79.000000
# max         500.000000

# %%
# Отображает статистику для категориальных столбцов
data.describe(include=['object'])
# Out:
#                          Country        City AQI Category CO AQI Category  \
# count                      23463       23463        23463           23463
# unique                       188       23463            6               3
# top     United States of America  Praskoveya         Good            Good
# freq                        2913           1         9936           23460
#
#        Ozone AQI Category NO2 AQI Category PM2.5 AQI Category  \
# count               23463            23463              23463
# unique                  5                2                  6
# top                  Good             Good               Good
# freq                21069            23448              10208
#
#                          City_Country
# count                           23463
# unique                          23463
# top     Praskoveya Russian Federation
# freq                                1

# %%
plt.figure(figsize=(10, 6))

# Построение графика
sns.histplot(data['AQI Value'], bins=30, kde=True, color='black')

# Добавление зеленой желтой и оранжевой зоны для значений AQI
plt.axvspan(0, 50, color='green', alpha=0.3, label='0-50 (Хорошо)')
plt.axvspan(51, 100, color='yellow', alpha=0.3, label='51-100 (Умеренно)')
plt.axvspan(101, max(data['AQI Value']), color='orange', alpha=0.3, label='101+ (Вредно)')

plt.title('Распределение значений AQI')
plt.xlabel('AQI Value')
plt.ylabel('Частота')
plt.legend(title='Категории AQI')
plt.grid()

plt.show()

# %% [markdown]
# Гистограмма показывает, как распределены значения AQI. Наблюдаем, что большинство наблюдей сосредоточено от 0 до 100, что показывает на хорошее или умеренное качество воздуха, однако есть и значения, выбивающиеся из этого диапазона

# %%
# Определение цветов
color_mapping = {
    'Good': 'green',
    'Moderate': 'yellow',
    'Unhealthy': 'orange',
    'Unhealthy for Sensitive Groups': 'red',
    'Very Unhealthy': 'black',
    'Hazardous': 'purple'
}

# Проверяем что данные подходят порядку
order = data['AQI Category'].value_counts().index
colors = [color_mapping[category] for category in order]

# Строим график
plt.figure(figsize=(10, 6))
sns.countplot(data=data, x='AQI Category', order=order, palette=colors)
plt.title('Количество городов по категориям AQI')
plt.xlabel('AQI Category')
plt.ylabel('Количество городов')
plt.xticks(rotation=45)
plt.grid()
plt.show()
# Out:
# <ipython-input-16-9886246a6fbe>:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=data, x='AQI Category', order=order, palette=colors)

# %% [markdown]
# Видим, что большинство городов находятся в категории "Хорошо" или "Умеренно"

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data['PM2.5 AQI Value'], bins=30, kde=True, color='black')

# Добавление зеленой желтой и оранжевой зоны для PM2.5 AQI
plt.axvspan(0, 50, color='green', alpha=0.3, label='0-50 (Хорошо)')
plt.axvspan(51, 100, color='yellow', alpha=0.3, label='51-100 (Умеренно)')
plt.axvspan(101, max(data['PM2.5 AQI Value']), color='orange', alpha=0.3, label='101+ (Вредно)')

plt.title('Распределение значений PM2.5 AQI')
plt.xlabel('PM2.5 AQI Value')
plt.ylabel('Частота')

# Добавление легенды для пояснения цветовых зон
plt.legend(title='Категории PM2.5 AQI')
plt.grid()

plt.show()

# %% [markdown]
# Гистограмма показывает распределение значений PM2.5, что может быть полезно для понимания уровня загрязнения этим конкретным загрязнителем

# %%
# Строим корреляционную матрицу факторов + целевой признак.
data_koef = data[['AQI Value','CO AQI Value', 'Ozone AQI Value', 'NO2 AQI Value', 'PM2.5 AQI Value']]
corr_matrix = data_koef.corr()

rang = np.linalg.matrix_rank(corr_matrix)
print('Ранг корреляционной матрицы:', rang)
determinant = round(np.linalg.det(corr_matrix), 3)
print('Определитель корреляционной матрицы:', determinant)

# рисуем тепловую карту
plt.figure(figsize=(8,4))
sns.heatmap(corr_matrix, cmap='RdBu_r', annot=True, vmin=-1, vmax=1);
# Out:
# Ранг корреляционной матрицы: 5
# Определитель корреляционной матрицы: 0.012

# %% [markdown]
# В исходных данных нет сильно коррелированных между собой факторов.
#
# PM2.5 (мелкодисперсные частицы, ≤2.5 мкм): Наиболее значимый параметр для оценки качества воздуха AQI. Коэффициен корреляции с целевым параметром AQI = 0,98
#
# Взаимосвязь между параметрами:
#
# Корреляция PM2.5 и NO₂ (коэф.корреляции с PM2.5
#  = 0,26), CO (коэф.корреляции с PM2.5 = 0,44): Газовые загрязнители, такие как СO и NO₂, участвуют в химических реакциях, образуя вторичные частицы PM.
#
# Взаимосвязь NO₂ и O₃ (отрицательный коэф.корреляции -0,18): В дневное время NO₂ участвует в образовании озона.
# В ночное время озон разрушается в реакциях с NO₂, снижая концентрации O₃.
#
# Корреляция O₃ и PM2.5 (0,26). Оба зягрязнителя O₃ и PM2.5 имеют имеют общие прекурсоры - оксиды азота. PM2.5 может включать частицы, образованные из реакций с участием озона(озон окисляет летучие органические соединения). Также озон реагирует с другими загрязнителями (например, аммиаком, серой), усиливая образование вторичных частиц.

# %% [markdown]
# ## Преобразование данных

# %%
df = data.copy()

# %%
columns_to_convert = [
    "PM2.5 AQI Category",
    "NO2 AQI Category",
    "Ozone AQI Category",
    "CO AQI Category",
    "AQI Category"
]

# columns на 'category'
df[columns_to_convert] = df[columns_to_convert].astype('category')

# Тест
print(df.dtypes)

# Проверка, что все пропуски были заменены
print(df.isnull().sum())
# Out:
# Country                 object
# City                    object
# AQI Value                int64
# AQI Category          category
# CO AQI Value             int64
# CO AQI Category       category
# Ozone AQI Value          int64
# Ozone AQI Category    category
# NO2 AQI Value            int64
# NO2 AQI Category      category
# PM2.5 AQI Value          int64
# PM2.5 AQI Category    category
# City_Country            object
# dtype: object
# Country               0
# City                  0
# AQI Value             0
# AQI Category          0
# CO AQI Value          0
# CO AQI Category       0
# Ozone AQI Value       0
# Ozone AQI Category    0
# NO2 AQI Value         0
# NO2 AQI Category      0
# PM2.5 AQI Value       0
# PM2.5 AQI Category    0
# City_Country          0
# dtype: int64

# %%
# Создаем словарь для последующую сравнения с прогнозом
aqi_category_mapping = dict(enumerate(df['AQI Category'].astype('category').cat.categories))

aqi_category_mapping
# Out:
# {0: 'Good',
#  1: 'Hazardous',
#  2: 'Moderate',
#  3: 'Unhealthy',
#  4: 'Unhealthy for Sensitive Groups',
#  5: 'Very Unhealthy'}

# %%
# Кодирование категориальных данных (Label Encoding)
df['AQI Category'] = df['AQI Category'].astype('category').cat.codes

# Преобразование категорий загрязнителей
for col in ['CO AQI Category', 'Ozone AQI Category', 'NO2 AQI Category', 'PM2.5 AQI Category']:
    if col in df.columns:
        df[col] = df[col].astype('category').cat.codes


# Выбор фич и целевой переменной
X = df[['CO AQI Value', 'Ozone AQI Value', 'NO2 AQI Value', 'PM2.5 AQI Value']]
y_value = df['AQI Value']  # Для прогноза AQI
y_category = df['AQI Category']  # Для классификации AQI Category

# Разделение на тренировочные и тестовые данные
X_train, X_test, y_train, y_test = train_test_split(X, y_value, test_size=0.2, random_state=42)
X_train_class, X_test_class, y_train_class, y_test_class = train_test_split(X, y_category, test_size=0.2, random_state=42)

# %% [markdown]
# ## Обучение модели

# %% [markdown]
# ### Прогнозирование AQI (регрессия)

# %%
# Первичная инициализация модели CatBoost для регрессии
model_reg = CatBoostRegressor(iterations=10, depth=1, learning_rate=0.1, loss_function='RMSE')

# %%
# %%time
##Поиском по сетке подбираем самые лучше параметры по модели регрессии
# Время выполнения ~5 минут!
param_grid_reg = {
        'iterations': [100, 500, 1000],
        'depth': [2, 4, 6],
        'learning_rate': [0.001, 0.01, 0.1]
    }
gs_reg = GridSearchCV(model_reg, param_grid_reg, scoring='neg_mean_squared_error', cv=5)
gs_reg.fit(X_train, y_train)
best_params_reg = gs_reg.best_params_
best_score_reg = (-gs_reg.best_score_) ** 0.5  # Преобразование из отрицательной MSE в RMSE
print(f"Лучшие параметры для model_reg: {best_params_reg}")
print(f"RMSE для model_reg: {best_score_reg}")
# Out:
# Streaming output truncated to the last 5000 lines.
# 363:	learn: 1.2689959	total: 1.16s	remaining: 435ms
# 364:	learn: 1.2675360	total: 1.17s	remaining: 432ms
# 365:	learn: 1.2658640	total: 1.17s	remaining: 428ms
# 366:	learn: 1.2644909	total: 1.17s	remaining: 425ms
# 367:	learn: 1.2636251	total: 1.18s	remaining: 422ms
# 368:	learn: 1.2613851	total: 1.18s	remaining: 418ms
# 369:	learn: 1.2588181	total: 1.18s	remaining: 415ms
# 370:	learn: 1.2537892	total: 1.18s	remaining: 412ms
# 371:	learn: 1.2522388	total: 1.19s	remaining: 408ms
# 372:	learn: 1.2510131	total: 1.19s	remaining: 405ms
# 373:	learn: 1.2453110	total: 1.19s	remaining: 402ms
# 374:	learn: 1.2437270	total: 1.2s	remaining: 398ms
# 375:	learn: 1.2417483	total: 1.2s	remaining: 395ms
# 376:	learn: 1.2405904	total: 1.2s	remaining: 392ms
# 377:	learn: 1.2375740	total: 1.2s	remaining: 389ms
# 378:	learn: 1.2353940	total: 1.21s	remaining: 385ms
# 379:	learn: 1.2342884	total: 1.21s	remaining: 382ms
# 380:	learn: 1.2332269	total: 1.22s	remaining: 380ms
# 381:	learn: 1.2303652	total: 1.22s	remaining: 378ms
# 382:	learn: 1.2262409	total: 1.23s	remaining: 375ms
# 383:	learn: 1.2254124	total: 1.23s	remaining: 372ms
# 384:	learn: 1.2218931	total: 1.23s	remaining: 368ms
# 385:	learn: 1.2206490	total: 1.24s	remaining: 365ms
# 386:	learn: 1.2185743	total: 1.24s	remaining: 362ms
# 387:	learn: 1.2183947	total: 1.24s	remaining: 358ms
# 388:	learn: 1.2173508	total: 1.24s	remaining: 355ms
# 389:	learn: 1.2173089	total: 1.25s	remaining: 352ms
# 390:	learn: 1.2154227	total: 1.25s	remaining: 348ms
# 391:	learn: 1.2134695	total: 1.25s	remaining: 345ms
# 392:	learn: 1.2123566	total: 1.25s	remaining: 342ms
# 393:	learn: 1.2101707	total: 1.26s	remaining: 339ms
# 394:	learn: 1.2075381	total: 1.26s	remaining: 335ms
# 395:	learn: 1.2053951	total: 1.26s	remaining: 332ms
# 396:	learn: 1.2042171	total: 1.27s	remaining: 329ms
# 397:	learn: 1.2014983	total: 1.27s	remaining: 325ms
# 398:	learn: 1.1946563	total: 1.27s	remaining: 322ms
# 399:	learn: 1.1926458	total: 1.28s	remaining: 319ms
# 400:	learn: 1.1878891	total: 1.28s	remaining: 316ms
# 401:	learn: 1.1857803	total: 1.28s	remaining: 313ms
# 402:	learn: 1.1853551	total: 1.28s	remaining: 309ms
# 403:	learn: 1.1835341	total: 1.29s	remaining: 306ms
# 180:	learn: 47.2764424	total: 1.24s	remaining: 5.6s
# 181:	learn: 47.2343319	total: 1.25s	remaining: 5.61s
# 182:	learn: 47.1913142	total: 1.25s	remaining: 5.6s
# 183:	learn: 47.1485788	total: 1.26s	remaining: 5.6s
# 184:	learn: 47.1057811	total: 1.27s	remaining: 5.6s
# 185:	learn: 47.0630114	total: 1.28s	remaining: 5.6s
# 186:	learn: 47.0197106	total: 1.29s	remaining: 5.6s
# 187:	learn: 46.9785377	total: 1.29s	remaining: 5.59s
# 188:	learn: 46.9376849	total: 1.3s	remaining: 5.57s
# 189:	learn: 46.8957382	total: 1.3s	remaining: 5.55s
# 190:	learn: 46.8553611	total: 1.31s	remaining: 5.54s
# 191:	learn: 46.8137412	total: 1.31s	remaining: 5.52s
# 192:	learn: 46.7726781	total: 1.32s	remaining: 5.5s
# 193:	learn: 46.7313978	total: 1.33s	remaining: 5.51s
# 194:	learn: 46.6897466	total: 1.33s	remaining: 5.5s
# 195:	learn: 46.6479752	total: 1.34s	remaining: 5.48s
# 196:	learn: 46.6053674	total: 1.34s	remaining: 5.46s
# 197:	learn: 46.5626416	total: 1.34s	remaining: 5.44s
# 198:	learn: 46.5206163	total: 1.35s	remaining: 5.42s
# 199:	learn: 46.4786476	total: 1.35s	remaining: 5.4s
# 200:	learn: 46.4365492	total: 1.35s	remaining: 5.38s
# 201:	learn: 46.3958449	total: 1.36s	remaining: 5.36s
# 202:	learn: 46.3543752	total: 1.36s	remaining: 5.34s
# 203:	learn: 46.3134885	total: 1.36s	remaining: 5.33s
# 204:	learn: 46.2709179	total: 1.37s	remaining: 5.31s
# 205:	learn: 46.2294862	total: 1.37s	remaining: 5.29s
# 206:	learn: 46.1887652	total: 1.38s	remaining: 5.27s
# 207:	learn: 46.1460623	total: 1.38s	remaining: 5.25s
# 208:	learn: 46.1042185	total: 1.38s	remaining: 5.23s
# 209:	learn: 46.0626866	total: 1.39s	remaining: 5.22s
# 210:	learn: 46.0209854	total: 1.39s	remaining: 5.2s
# 211:	learn: 45.9796408	total: 1.4s	remaining: 5.2s
# 212:	learn: 45.9382888	total: 1.41s	remaining: 5.22s
# 213:	learn: 45.8972384	total: 1.42s	remaining: 5.22s
# 214:	learn: 45.8557248	total: 1.42s	remaining: 5.2s
# 215:	learn: 45.8147795	total: 1.43s	remaining: 5.18s
# 216:	learn: 45.7739172	total: 1.43s	remaining: 5.16s
# 217:	learn: 45.7317990	total: 1.44s	remaining: 5.15s
# 218:	learn: 45.6904895	total: 1.44s	remaining: 5.15s
# 219:	learn: 45.6505093	total: 1.45s	remaining: 5.14s
# 220:	learn: 45.6087882	total: 1.46s	remaining: 5.14s
# 221:	learn: 45.5694195	total: 1.47s	remaining: 5.14s
# 222:	learn: 45.5287689	total: 1.47s	remaining: 5.13s
# 223:	learn: 45.4878297	total: 1.48s	remaining: 5.13s
# 224:	learn: 45.4474788	total: 1.49s	remaining: 5.13s
# 225:	learn: 45.4075343	total: 1.5s	remaining: 5.13s
# 319:	learn: 41.7556555	total: 1.86s	remaining: 3.95s
# 320:	learn: 41.7189947	total: 1.86s	remaining: 3.94s
# 321:	learn: 41.6814968	total: 1.86s	remaining: 3.92s
# 322:	learn: 41.6442401	total: 1.87s	remaining: 3.91s
# 323:	learn: 41.6062888	total: 1.87s	remaining: 3.9s
# 324:	learn: 41.5697445	total: 1.87s	remaining: 3.89s
# 325:	learn: 41.5322184	total: 1.88s	remaining: 3.88s
# 326:	learn: 41.4957034	total: 1.88s	remaining: 3.87s
# 327:	learn: 41.4590225	total: 1.88s	remaining: 3.85s
# 328:	learn: 41.4226222	total: 1.88s	remaining: 3.84s
# 329:	learn: 41.3848326	total: 1.89s	remaining: 3.83s
# 330:	learn: 41.3477424	total: 1.89s	remaining: 3.82s
# 331:	learn: 41.3111887	total: 1.89s	remaining: 3.81s
# 332:	learn: 41.2741823	total: 1.9s	remaining: 3.8s
# 333:	learn: 41.2382185	total: 1.9s	remaining: 3.79s
# 334:	learn: 41.2027596	total: 1.9s	remaining: 3.77s
# 335:	learn: 41.1653223	total: 1.9s	remaining: 3.76s
# 336:	learn: 41.1276635	total: 1.91s	remaining: 3.75s
# 337:	learn: 41.0914147	total: 1.91s	remaining: 3.74s
# 338:	learn: 41.0552945	total: 1.91s	remaining: 3.73s
# 339:	learn: 41.0201470	total: 1.92s	remaining: 3.72s
# 340:	learn: 40.9835067	total: 1.92s	remaining: 3.71s
# 341:	learn: 40.9465369	total: 1.92s	remaining: 3.7s
# 342:	learn: 40.9113711	total: 1.93s	remaining: 3.69s
# 343:	learn: 40.8743863	total: 1.93s	remaining: 3.68s
# 344:	learn: 40.8380791	total: 1.93s	remaining: 3.67s
# 345:	learn: 40.8027484	total: 1.93s	remaining: 3.65s
# 346:	learn: 40.7664759	total: 1.94s	remaining: 3.64s
# 347:	learn: 40.7305016	total: 1.94s	remaining: 3.63s
# 348:	learn: 40.6936655	total: 1.94s	remaining: 3.62s
# 349:	learn: 40.6574456	total: 1.95s	remaining: 3.61s
# 350:	learn: 40.6214247	total: 1.95s	remaining: 3.6s
# 351:	learn: 40.5845048	total: 1.95s	remaining: 3.59s
# 352:	learn: 40.5490941	total: 1.95s	remaining: 3.58s
# 353:	learn: 40.5134712	total: 1.96s	remaining: 3.57s
# 354:	learn: 40.4766957	total: 1.96s	remaining: 3.56s
# 355:	learn: 40.4412455	total: 1.96s	remaining: 3.55s
# 356:	learn: 40.4049148	total: 1.97s	remaining: 3.54s
# 357:	learn: 40.3699124	total: 1.97s	remaining: 3.53s
# 358:	learn: 40.3331926	total: 1.97s	remaining: 3.52s
# 359:	learn: 40.2985339	total: 1.97s	remaining: 3.51s
# 360:	learn: 40.2632590	total: 1.98s	remaining: 3.5s
# 361:	learn: 40.2275232	total: 1.98s	remaining: 3.49s
# 362:	learn: 40.1919482	total: 1.98s	remaining: 3.48s

# %%
# %%time
#Обучаем модель с лучшими параметрами
model_reg = CatBoostRegressor(iterations=best_params_reg['iterations'], depth=best_params_reg['depth'], learning_rate=best_params_reg['learning_rate'], loss_function='RMSE')

model_reg.fit(X_train, y_train)

# Оценка модели
y_pred_reg = model_reg.predict(X_test)

# %% [markdown]
# ### Классификация AQI Category

# %%
# Инициализация создание модели CatBoost для классификации
# Параметр loss_function='MultiClass' указывает, что модель будет обучаться для предсказания нескольких классов (многоклассовая классификация).
#Это означает, что целевая переменная (y_train_class) содержит более двух уникальных классов, и модель будет предсказывать вероятность принадлежности к каждому из этих классов.
model_class = CatBoostClassifier(iterations=10, depth=1, learning_rate=0.1, loss_function='MultiClass')

# %%
# %%time
##Поиском по сетке подбираем самые лучше параметры для модели классификации
# Время выполнения от 10 минут!
param_grid_class = {
        'iterations': [100, 500, 1000],
        'depth': [2, 4, 6],
        'learning_rate': [0.001, 0.01, 0.1]
    }
gs_class = GridSearchCV(model_class, param_grid_class, scoring='accuracy', cv=5)
gs_class.fit(X_train_class, y_train_class)
best_params_class = gs_class.best_params_
best_score_class = gs_class.best_score_
print(f"Лучшие параметры для model_reg: {best_params_class}")
print(f"accuracy для model_class: {best_score_class}")

# %%
# %%time
#Обучаем модель с лучшими параметрами
model_class = CatBoostClassifier(iterations=best_params_class['iterations'], depth=best_params_class['depth'], learning_rate=best_params_class['learning_rate'], loss_function='MultiClass')

# Обучение модели
model_class.fit(X_train_class, y_train_class)

# Оценка модели
y_pred_class = model_class.predict(X_test_class)

# %%
# Получение важности признаков
feature_importances = model_class.get_feature_importance(Pool(X_train_class, y_train_class))

features = X.columns

# Построение графика
plt.figure(figsize=(10, 6))
with sns.color_palette("flare"):
    sns.barplot(x=feature_importances, y=features, hue=features)
plt.title("Оценка важности признаков в CatBoost Model")
plt.xlabel("Оценка важности")
plt.ylabel("Признак (вх.параметр)")
plt.show()

# %%
#Используем SHAP чтобы наглядно показать два главных влияющих параметра на AQI
explainer = shap.TreeExplainer(model_reg)
shap_values = explainer.shap_values(X_test)

shap.summary_plot(shap_values, X_test)

# %% [markdown]
# ## Оценка модели

# %%
# Оценка качества модели для прогноза AQI
mse = mean_squared_error(y_test, y_pred_reg)
r2 = r2_score(y_test, y_pred_reg)

print(f'Mean Squared Error: {mse}')
print(f'R2 Score: {r2}')

# %%
# Оценка качества модели для классификации AQI Category
accuracy = accuracy_score(y_test_class, y_pred_class)
print(f'Accuracy: {accuracy}')

# %% [markdown]
# ### Проверка работы модели

# %%
def predict_aqi(data):
    """
    Прогнозирует общий индекс качества воздуха (AQI) и его категорию на основе входных данных.

    Параметры:
    data (pd.DataFrame): DataFrame, содержащий следующие столбцы:
        - 'CO AQI Value': Знaчение AQI для угарного газа.
        - 'Ozone AQI Value': Знaчение AQI для озона.
        - 'NO2 AQI Value': Знaчение AQI для диоксида азота.
        - 'PM2.5 AQI Value': Знaчение AQI для мелких твердых частиц

    Возвращает:
    tuple:
        - aqi_prediction: Массив предсказанных значений AQI.
        - aqi_category_prediction: Массив предсказанных категорий AQI.
    """
    X_input = data[['CO AQI Value', 'Ozone AQI Value', 'NO2 AQI Value', 'PM2.5 AQI Value']]
    aqi_prediction = model_reg.predict(X_input)

    # Классификация AQI Category
    aqi_category_prediction = model_class.predict(X_input)

    return aqi_prediction, aqi_category_prediction

# %%
new_data = pd.DataFrame({
    'CO AQI Value': [20, 30, 10, 75, 60, 25, 50, 90, 15, 80],
    'Ozone AQI Value': [50, 30, 70, 80, 20, 45, 55, 120, 40, 90],
    'NO2 AQI Value': [30, 40, 25, 35, 45, 50, 55, 100, 45, 115],
    'PM2.5 AQI Value': [55, 50, 30, 66, 100, 90, 75, 200, 25, 350],
})


aqi_value, aqi_category = predict_aqi(new_data)

for value, category in zip(aqi_value, aqi_category):
    # Преобразуем numpy.ndarray в строку, если это необходимо
    if isinstance(category, np.ndarray):
        category = category.item()  # Извлекаем значение из массива (если это массив с одним элементом)

    print(f'Predicted AQI Value: {value}')
    print(f'Predicted AQI Category: {aqi_category_mapping.get(category, str(category))}\n')

# %% [markdown]
# ### Проверка работы модели на данных, полученных с помощью датчиков IoT о загрязнении воздуха в Дакке, Бангладеш

# %%
# Загрузка данных (48 строк = 2 суток с почасовыми замерами параметров)
data_control = pd.read_csv('https://raw.githubusercontent.com/k0rsair/Space-plans/refs/heads/main/my_ap_dataset.csv', nrows=48)

# %%
data_control.head()

# %%
# Приведение таблицы к нужному формату
data_control = data_control.drop(['Latitude', 'Longitude', 'SO2', 'PM10', 'Address', 'Station code'], axis=1)
data_control = data_control.rename(columns={'NO2':'NO2 AQI Value', 'CO':'CO AQI Value', 'O3':'Ozone AQI Value', 'PM2.5':'PM2.5 AQI Value' })
data_control['Country'] = 'Bangladesh'
data_control['City'] = 'Dhaka'
# Отображение статистики
data_control.describe()

# %%
def predict_aqi_(row):
    # Прогнозирование общего AQI
    row_df = pd.DataFrame([row])
    X_input = row_df[['CO AQI Value', 'Ozone AQI Value', 'NO2 AQI Value', 'PM2.5 AQI Value']]
    aqi_prediction = model_reg.predict(X_input)[0]  # Получение прогнозного значения

    # Классификация AQI Category
    aqi_category_prediction = model_class.predict(X_input)[0]
    aqi_category_for_map = aqi_category_prediction[0]
    return pd.Series({'AQI Value': aqi_prediction, 'AQI Category': aqi_category_mapping[aqi_category_for_map]})  # возврат как Series

# Получение данных AQI Value, AQI Category с помощью модели
predictions = data_control.apply(predict_aqi_, axis=1)
data_control[['AQI Value', 'AQI Category']] = predictions[['AQI Value', 'AQI Category']]

# %%
# График распределения AQI Value по категориям
plt.figure(figsize=(8, 6))
category_counts = data_control['AQI Category'].value_counts()
plt.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%', colors=['lightblue', '#d62728'])
_ = plt.title('распределение AQI Value по категориям')

# %%
# График мониторинга показателя качества воздуха AQI Value в течении 48 часов
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['date']
  ys = series['AQI Value']
  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(12, 5), layout='constrained')
_plot_series(data_control, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('date')
plt.xticks(rotation=45)

_ = plt.ylabel('AQI Value')
